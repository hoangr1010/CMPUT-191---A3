# %%
from datascience import *
import numpy as np

# %matplotlib inline
import matplotlib.pyplot as plots
plots.style.use('fivethirtyeight')

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from IPython.core.display import display, HTML

def scrape_table(table):
    df = pd.read_html(str(table))
    df = pd.DataFrame(df[0])
    return Table.from_df(df)
# Out:
# C:\Users\Anees' Laptop\AppData\Local\Temp\ipykernel_4696\1145054876.py:4: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display, HTML

# %% [markdown]
# #1. Scrape data#

# %%
egg_price_url = "https://www.globalproductprices.com/rankings/egg_prices/"
tax_rate_url = "https://tradingeconomics.com/country-list/sales-tax-rate"
currency_url = "https://taxsummaries.pwc.com/glossary/currency-codes"

# %%
#Scrape data from egg_price_url
egg_price_request = requests.get(egg_price_url)
egg_soup = BeautifulSoup(egg_price_request.text, 'html.parser')

raw_price_table = egg_soup.find('table')
egg_price_table = scrape_table(raw_price_table)
egg_price_table = egg_price_table.sort("Countries")
egg_price_table
# Out:
# Countries  | Eggs prices, dozen | Rank
# Argentina  | 3.48               | 25
# Australia  | 5.08               | 5
# Austria    | 3.81               | 17
# Azerbaijan | 1.59               | 76
# Bangladesh | 1.25               | 79
# Belgium    | 4.13               | 10
# Bolivia    | 1.87               | 70
# Brazil     | 2.18               | 57
# Bulgaria   | 4.87               | 6
# Cameroon   | 1.93               | 68
# ... (71 rows omitted)

# %%
#Scrape data from tax_rate_url
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
}
tax_rate_request = requests.get(tax_rate_url, headers=headers)
tax_soup = BeautifulSoup(tax_rate_request.text, 'html.parser')

raw_tax_table = tax_soup.find('table')
tax_price_table = scrape_table(raw_tax_table)
tax_price_table
# Out:
# Country             | Last | Previous | Reference | Unit
# Afghanistan         | 10   | 10       | Dec/24    | %
# Albania             | 20   | 20       | Dec/24    | %
# Algeria             | 19   | 19       | Dec/24    | %
# Andorra             | 4.5  | 4.5      | Dec/24    | %
# Angola              | 14   | 14       | Dec/23    | %
# Antigua And Barbuda | 15   | 15       | Dec/24    | %
# Argentina           | 21   | 21       | Dec/24    | %
# Armenia             | 20   | 20       | Dec/24    | %
# Aruba               | 4    | 4        | Dec/24    | %
# Australia           | 10   | 10       | Dec/24    | %
# ... (169 rows omitted)

# %%
#Collect currency data
currency_request = requests.get(currency_url, headers=headers)
currency_soup = BeautifulSoup(currency_request.text, 'html.parser')

raw_currency_table = currency_soup.find('table')
currency_df = pd.read_html(str(raw_currency_table), header=0)[0]
currency_table = Table.from_df(currency_df)
currency_table
# Out:
# Territory  | Currency code (ISO 4217) | Currency name
# Albania    | ALL                      | lek
# Algeria    | DZD                      | dinar
# Angola     | AOA                      | kwanza
# Argentina  | ARS                      | peso
# Armenia    | AMD                      | dram
# Australia  | AUD                      | dollar
# Austria    | EUR                      | euro
# Azerbaijan | AZN                      | manat
# Bahrain    | BHD                      | dinar
# Barbados   | BBD                      | dollar
# ... (144 rows omitted)

# %% [markdown]
# 2. Data Cleaning

# %%
missing_country_mapping = {
    "United States" : "USA",
    "United Kingdom" : "UK",
    "Dominican Republic" : 'Domin. Rep.',
    "United Arab Emirates": "UA Emirates",
    "Czech Republic" : "Czechia"

}

tax_price_table = tax_price_table.with_columns("Country",[missing_country_mapping.get(x, x) for x in tax_price_table.column("Country")])
tax_price_table
# Out:
# Country             | Last | Previous | Reference | Unit
# Afghanistan         | 10   | 10       | Dec/24    | %
# Albania             | 20   | 20       | Dec/24    | %
# Algeria             | 19   | 19       | Dec/24    | %
# Andorra             | 4.5  | 4.5      | Dec/24    | %
# Angola              | 14   | 14       | Dec/23    | %
# Antigua And Barbuda | 15   | 15       | Dec/24    | %
# Argentina           | 21   | 21       | Dec/24    | %
# Armenia             | 20   | 20       | Dec/24    | %
# Aruba               | 4    | 4        | Dec/24    | %
# Australia           | 10   | 10       | Dec/24    | %
# ... (169 rows omitted)

# %%
from rapidfuzz import process, fuzz

def create_fuzzy_mapping(source, target):
    mapping = {}
    low_score_matches = []
    for country in source:
        match = process.extractOne(country, target, scorer=fuzz.token_sort_ratio)
        if match and match[1] > 30: 
            mapping[country] = match[0]
        elif 50 < match[1] <= 80:  # Low-confidence match
            low_score_matches.append((country, match[0], match[1]))
    return mapping
    

fuzzy_mapping = create_fuzzy_mapping(egg_price_table.column('Countries'), tax_price_table.column('Country'))

# Function to standardize using fuzzy mapping
def standardize_country(name):
    return fuzzy_mapping.get(name, name)


# Add standardized columns to each table
egg_price_table = egg_price_table.with_column('Standardized_Country', egg_price_table.apply(standardize_country, 'Countries'))
tax_price_table = tax_price_table.with_column('Standardized_Country', tax_price_table.apply(standardize_country, 'Country'))

# Find common standardized countries
common_countries = set(egg_price_table.column('Standardized_Country')).intersection(tax_price_table.column('Standardized_Country'))

# Filter rows with common countries
filtered_table1 = egg_price_table.where('Standardized_Country', lambda x: x in common_countries)
filtered_table2 = tax_price_table.where('Standardized_Country', lambda x: x in common_countries)

# Display the filtered tables
filtered_table1.show()
filtered_table2.show()
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>Countries</th> <th>Eggs prices, dozen</th> <th>Rank</th> <th>Standardized_Country</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>Argentina   </td> <td>3.48              </td> <td>25  </td> <td>Argentina           </td>
#         </tr>
#         <tr>
#             <td>Australia   </td> <td>5.08              </td> <td>5   </td> <td>Australia           </td>
#         </tr>
#         <tr>
#             <td>Austria     </td> <td>3.81              </td> <td>17  </td> <td>Austria             </td>
#         </tr>
#         <tr>
#             <td>Azerbaijan  </td> <td>1.59              </td> <td>76  </td> <td>Azerbaijan          </td>
#         </tr>
#         <tr>
#             <td>Bangladesh  </td> <td>1.25              </td> <td>79  </td> <td>Bangladesh          </td>
#         </tr>
#         <tr>
#             <td>Belgium     </td> <td>4.13              </td> <td>10  </td> <td>Belgium             </td>
#         </tr>
#         <tr>
#             <td>Bolivia     </td> <td>1.87              </td> <td>70  </td> <td>Bolivia             </td>
#         </tr>
#         <tr>
#             <td>Brazil      </td> <td>2.18              </td> <td>57  </td> <td>Brazil              </td>
#         </tr>
#         <tr>
#             <td>Bulgaria    </td> <td>4.87              </td> <td>6   </td> <td>Bulgaria            </td>
#         </tr>
#         <tr>
#             <td>Cameroon    </td> <td>1.93              </td> <td>68  </td> <td>Cameroon            </td>
#         </tr>
#         <tr>
#             <td>Canada      </td> <td>2.78              </td> <td>37  </td> <td>Canada              </td>
#         </tr>
#         <tr>
#             <td>Chile       </td> <td>3.62              </td> <td>20  </td> <td>Chile               </td>
#         </tr>
#         <tr>
#             <td>China       </td> <td>2.15              </td> <td>61  </td> <td>China               </td>
#         </tr>
#         <tr>
#             <td>Colombia    </td> <td>2.47              </td> <td>45  </td> <td>Colombia            </td>
#         </tr>
#         <tr>
#             <td>Costa Rica  </td> <td>2.6               </td> <td>40  </td> <td>Costa Rica          </td>
#         </tr>
#         <tr>
#             <td>Croatia     </td> <td>3.07              </td> <td>32  </td> <td>Croatia             </td>
#         </tr>
#         <tr>
#             <td>Czechia     </td> <td>2.86              </td> <td>36  </td> <td>China               </td>
#         </tr>
#         <tr>
#             <td>Denmark     </td> <td>3.97              </td> <td>13  </td> <td>Denmark             </td>
#         </tr>
#         <tr>
#             <td>Domin. Rep. </td> <td>1.9               </td> <td>69  </td> <td>Dominican Republic  </td>
#         </tr>
#         <tr>
#             <td>Ecuador     </td> <td>2.3               </td> <td>55  </td> <td>Ecuador             </td>
#         </tr>
#         <tr>
#             <td>Egypt       </td> <td>1.84              </td> <td>71  </td> <td>Egypt               </td>
#         </tr>
#         <tr>
#             <td>Finland     </td> <td>3.49              </td> <td>24  </td> <td>Finland             </td>
#         </tr>
#         <tr>
#             <td>France      </td> <td>3.91              </td> <td>14  </td> <td>France              </td>
#         </tr>
#         <tr>
#             <td>Germany     </td> <td>4.23              </td> <td>9   </td> <td>Germany             </td>
#         </tr>
#         <tr>
#             <td>Ghana       </td> <td>3.03              </td> <td>33  </td> <td>Ghana               </td>
#         </tr>
#         <tr>
#             <td>Greece      </td> <td>3.28              </td> <td>27  </td> <td>Greece              </td>
#         </tr>
#         <tr>
#             <td>Guatemala   </td> <td>2.07              </td> <td>63  </td> <td>Guatemala           </td>
#         </tr>
#         <tr>
#             <td>Hong Kong   </td> <td>3.84              </td> <td>16  </td> <td>Congo               </td>
#         </tr>
#         <tr>
#             <td>Hungary     </td> <td>2.46              </td> <td>46  </td> <td>Hungary             </td>
#         </tr>
#         <tr>
#             <td>India       </td> <td>1.66              </td> <td>74  </td> <td>India               </td>
#         </tr>
#         <tr>
#             <td>Indonesia   </td> <td>1.74              </td> <td>72  </td> <td>Indonesia           </td>
#         </tr>
#         <tr>
#             <td>Ireland     </td> <td>4.13              </td> <td>11  </td> <td>Ireland             </td>
#         </tr>
#         <tr>
#             <td>Israel      </td> <td>3.55              </td> <td>22  </td> <td>Israel              </td>
#         </tr>
#         <tr>
#             <td>Italy       </td> <td>3.39              </td> <td>26  </td> <td>Italy               </td>
#         </tr>
#         <tr>
#             <td>Ivory Coast </td> <td>2.45              </td> <td>48  </td> <td>Ivory Coast         </td>
#         </tr>
#         <tr>
#             <td>Japan       </td> <td>3.85              </td> <td>15  </td> <td>Japan               </td>
#         </tr>
#         <tr>
#             <td>Jordan      </td> <td>2.68              </td> <td>39  </td> <td>Jordan              </td>
#         </tr>
#         <tr>
#             <td>Kazakhstan  </td> <td>1.65              </td> <td>75  </td> <td>Kazakhstan          </td>
#         </tr>
#         <tr>
#             <td>Kenya       </td> <td>2.43              </td> <td>49  </td> <td>Kenya               </td>
#         </tr>
#         <tr>
#             <td>Kuwait      </td> <td>2.28              </td> <td>56  </td> <td>Haiti               </td>
#         </tr>
#         <tr>
#             <td>Latvia      </td> <td>3.28              </td> <td>28  </td> <td>Latvia              </td>
#         </tr>
#         <tr>
#             <td>Lithuania   </td> <td>3.17              </td> <td>30  </td> <td>Lithuania           </td>
#         </tr>
#         <tr>
#             <td>Malaysia    </td> <td>2.32              </td> <td>54  </td> <td>Malaysia            </td>
#         </tr>
#         <tr>
#             <td>Mexico      </td> <td>2.45              </td> <td>47  </td> <td>Mexico              </td>
#         </tr>
#         <tr>
#             <td>Morocco     </td> <td>3.25              </td> <td>29  </td> <td>Morocco             </td>
#         </tr>
#         <tr>
#             <td>Netherlands </td> <td>2.75              </td> <td>38  </td> <td>Netherlands         </td>
#         </tr>
#         <tr>
#             <td>New Zealand </td> <td>6.77              </td> <td>1   </td> <td>New Zealand         </td>
#         </tr>
#         <tr>
#             <td>Nigeria     </td> <td>2.16              </td> <td>60  </td> <td>Nigeria             </td>
#         </tr>
#         <tr>
#             <td>Norway      </td> <td>5.43              </td> <td>3   </td> <td>Norway              </td>
#         </tr>
#         <tr>
#             <td>Pakistan    </td> <td>1.47              </td> <td>78  </td> <td>Pakistan            </td>
#         </tr>
#         <tr>
#             <td>Paraguay    </td> <td>1.66              </td> <td>73  </td> <td>Paraguay            </td>
#         </tr>
#         <tr>
#             <td>Peru        </td> <td>2.34              </td> <td>51  </td> <td>Peru                </td>
#         </tr>
#         <tr>
#             <td>Philippines </td> <td>2.18              </td> <td>58  </td> <td>Philippines         </td>
#         </tr>
#         <tr>
#             <td>Poland      </td> <td>2.95              </td> <td>35  </td> <td>Poland              </td>
#         </tr>
#         <tr>
#             <td>Portugal    </td> <td>2.54              </td> <td>43  </td> <td>Portugal            </td>
#         </tr>
#         <tr>
#             <td>Puerto Rico </td> <td>3.8               </td> <td>18  </td> <td>European Union      </td>
#         </tr>
#         <tr>
#             <td>Romania     </td> <td>3.55              </td> <td>23  </td> <td>Romania             </td>
#         </tr>
#         <tr>
#             <td>Russia      </td> <td>1.16              </td> <td>81  </td> <td>Russia              </td>
#         </tr>
#         <tr>
#             <td>Saudi Arabia</td> <td>2.1               </td> <td>62
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>Country</th> <th>Last</th> <th>Previous</th> <th>Reference</th> <th>Unit</th> <th>Standardized_Country</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>Argentina           </td> <td>21   </td> <td>21      </td> <td>Dec/24   </td> <td>%   </td> <td>Argentina           </td>
#         </tr>
#         <tr>
#             <td>Australia           </td> <td>10   </td> <td>10      </td> <td>Dec/24   </td> <td>%   </td> <td>Australia           </td>
#         </tr>
#         <tr>
#             <td>Austria             </td> <td>20   </td> <td>20      </td> <td>Dec/24   </td> <td>%   </td> <td>Austria             </td>
#         </tr>
#         <tr>
#             <td>Azerbaijan          </td> <td>18   </td> <td>18      </td> <td>Dec/24   </td> <td>%   </td> <td>Azerbaijan          </td>
#         </tr>
#         <tr>
#             <td>Bangladesh          </td> <td>15   </td> <td>15      </td> <td>Dec/24   </td> <td>%   </td> <td>Bangladesh          </td>
#         </tr>
#         <tr>
#             <td>Belgium             </td> <td>21   </td> <td>21      </td> <td>Dec/24   </td> <td>%   </td> <td>Belgium             </td>
#         </tr>
#         <tr>
#             <td>Bolivia             </td> <td>13   </td> <td>13      </td> <td>Dec/24   </td> <td>%   </td> <td>Bolivia             </td>
#         </tr>
#         <tr>
#             <td>Brazil              </td> <td>17   </td> <td>17      </td> <td>Dec/24   </td> <td>%   </td> <td>Brazil              </td>
#         </tr>
#         <tr>
#             <td>Bulgaria            </td> <td>20   </td> <td>20      </td> <td>Dec/24   </td> <td>%   </td> <td>Bulgaria            </td>
#         </tr>
#         <tr>
#             <td>Cameroon            </td> <td>19.25</td> <td>19.25   </td> <td>Dec/24   </td> <td>%   </td> <td>Cameroon            </td>
#         </tr>
#         <tr>
#             <td>Canada              </td> <td>5    </td> <td>5       </td> <td>Dec/24   </td> <td>%   </td> <td>Canada              </td>
#         </tr>
#         <tr>
#             <td>Chile               </td> <td>19   </td> <td>19      </td> <td>Dec/24   </td> <td>%   </td> <td>Chile               </td>
#         </tr>
#         <tr>
#             <td>China               </td> <td>13   </td> <td>13      </td> <td>Dec/24   </td> <td>%   </td> <td>China               </td>
#         </tr>
#         <tr>
#             <td>Colombia            </td> <td>19   </td> <td>19      </td> <td>Dec/24   </td> <td>%   </td> <td>Colombia            </td>
#         </tr>
#         <tr>
#             <td>Congo               </td> <td>16   </td> <td>16      </td> <td>Dec/24   </td> <td>%   </td> <td>Congo               </td>
#         </tr>
#         <tr>
#             <td>Costa Rica          </td> <td>13   </td> <td>13      </td> <td>Dec/24   </td> <td>%   </td> <td>Costa Rica          </td>
#         </tr>
#         <tr>
#             <td>Croatia             </td> <td>25   </td> <td>25      </td> <td>Dec/24   </td> <td>%   </td> <td>Croatia             </td>
#         </tr>
#         <tr>
#             <td>Denmark             </td> <td>25   </td> <td>25      </td> <td>Dec/24   </td> <td>%   </td> <td>Denmark             </td>
#         </tr>
#         <tr>
#             <td>Dominican Republic  </td> <td>18   </td> <td>18      </td> <td>Dec/24   </td> <td>%   </td> <td>Dominican Republic  </td>
#         </tr>
#         <tr>
#             <td>Ecuador             </td> <td>12   </td> <td>12      </td> <td>Dec/24   </td> <td>%   </td> <td>Ecuador             </td>
#         </tr>
#         <tr>
#             <td>Egypt               </td> <td>14   </td> <td>14      </td> <td>Dec/24   </td> <td>%   </td> <td>Egypt               </td>
#         </tr>
#         <tr>
#             <td>European Union      </td> <td>21.5 </td> <td>21.5    </td> <td>Dec/23   </td> <td>%   </td> <td>European Union      </td>
#         </tr>
#         <tr>
#             <td>Finland             </td> <td>24   </td> <td>24      </td> <td>Dec/24   </td> <td>%   </td> <td>Finland             </td>
#         </tr>
#         <tr>
#             <td>France              </td> <td>20   </td> <td>20      </td> <td>Dec/24   </td> <td>%   </td> <td>France              </td>
#         </tr>
#         <tr>
#             <td>Germany             </td> <td>19   </td> <td>19      </td> <td>Dec/24   </td> <td>%   </td> <td>Germany             </td>
#         </tr>
#         <tr>
#             <td>Ghana               </td> <td>15   </td> <td>15      </td> <td>Dec/24   </td> <td>%   </td> <td>Ghana               </td>
#         </tr>
#         <tr>
#             <td>Greece              </td> <td>24   </td> <td>24      </td> <td>Dec/24   </td> <td>%   </td> <td>Greece              </td>
#         </tr>
#         <tr>
#             <td>Guatemala           </td> <td>12   </td> <td>12      </td> <td>Dec/24   </td> <td>%   </td> <td>Guatemala           </td>
#         </tr>
#         <tr>
#             <td>Haiti               </td> <td>10   </td> <td>10      </td> <td>Dec/24   </td> <td>%   </td> <td>Haiti               </td>
#         </tr>
#         <tr>
#             <td>Hungary             </td> <td>27   </td> <td>27      </td> <td>Dec/24   </td> <td>%   </td> <td>Hungary             </td>
#         </tr>
#         <tr>
#             <td>India               </td> <td>18   </td> <td>18      </td> <td>Dec/24   </td> <td>%   </td> <td>India               </td>
#         </tr>
#         <tr>
#             <td>Indonesia           </td> <td>11   </td> <td>11      </td> <td>Dec/24   </td> <td>%   </td> <td>Indonesia           </td>
#         </tr>
#         <tr>
#             <td>Ireland             </td> <td>23   </td> <td>23      </td> <td>Dec/24   </td> <td>%   </td> <td>Ireland             </td>
#         </tr>
#         <tr>
#             <td>Israel              </td> <td>17   </td> <td>17      </td> <td>Dec/24   </td> <td>%   </td> <td>Israel              </td>
#         </tr>
#         <tr>
#             <td>Italy               </td> <td>22   </td> <td>22      </td> <td>Dec/24   </td> <td>%   </td> <td>Italy               </td>
#         </tr>
#         <tr>
#             <td>Ivory Coast         </td> <td>18   </td> <td>18      </td> <td>Dec/24   </td> <td>%   </td> <td>Ivory Coast         </td>
#         </tr>
#         <tr>
#             <td>Japan               </td> <td>10   </td> <td>10      </td> <td>Dec/24   </td> <td>%   </td> <td>Japan               </td>
#         </tr>
#         <tr>
#             <td>Jordan              </td> <td>16   </td> <td>16      </td> <td>Dec/24   </td> <td>%   </td> <td>Jordan              </td>
#         </tr>
#         <tr>
#             <td>Kazakhstan          </td> <td>12   </td> <td>12      </td> <td>Dec/24   </td> <td>%   </td> <td>Kazakhstan          </td>
#         </tr>
#         <tr>
#             <td>Kenya               </td> <td>16   </td> <td>16      </td> <td>Dec/24   </td> <td>%   </td> <td>Kenya               </td>
#         </tr>
#         <tr>
#             <td>Latvia              </td> <td>21   </td> <td>21      </td> <td>Dec/24   </td> <td>%   </td> <td>Latvia              </td>
#         </tr>
#         <tr>
#             <td>Lithuania           </td> <td>21   </td> <td>21      </td> <td>Dec/24   </td> <td>%   </td> <td>Lithuania           </td>
#         </tr>
#         <tr>
#             <td>Malaysia            </td> <td>10   </td> <td>10      </td> <td>Dec/24   </td> <td>%   </td> <td>Malaysia            </td>
#         </tr>
#         <tr>
#             <td>Mexico              </td> <td>16   </td> <td>16      </td> <td>Dec/24   </td> <td>%   </td> <td>Mexico              </td>
#         </tr>
#         <tr>
#             <td>Morocco             </td> <td>20   </td> <td>20      </td> <td>Dec/24   </td> <td>%   </td> <td>Morocco             </td>
#         </tr>
#         <tr>
#             <td>Netherlands         </td> <td>21   </td> <td>21      </td> <td>Dec/24   </td> <td>%   </td> <td>Netherlands         </td>
#         </tr>
#         <tr>
#             <td>New Zealand         </td> <td>15   </td> <td>15      </td> <td>Dec/24   </td> <td>%   </td> <td>New Zealand         </td>
#         </tr>
#         <tr>

# %%
low_score_matches
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 low_score_matches
#
# NameError: name 'low_score_matches' is not defined

# %%
egg_countries_set = set(egg_price_table.column("Countries"))
tax_rate_countries_set = set(final_tax_price_table.column("Country"))

missing_countries1 = egg_countries_set - tax_rate_countries_set

print(f"Missing countries are: {missing_countries1}")
# Out:
# Missing countries are: {'Kuwait', 'Puerto Rico', 'Hong Kong'}

# %%
# Out:
# Country    | Sales Tax Rate (%)
# Argentina  | 21
# Australia  | 10
# Austria    | 20
# Azerbaijan | 18
# Bangladesh | 15
# Belgium    | 21
# Bolivia    | 13
# Brazil     | 17
# Bulgaria   | 20
# Cameroon   | 19.25
# ... (63 rows omitted)

# %%
final_currency_table = currency_table.where("Territory", lambda c: c in egg_price_table.column('Countries'))
#final_currency_table = final_currency_table.drop(["Number", "Currency"])
final_currency_table
# Out:
# Territory  | Currency code (ISO 4217) | Currency name
# Argentina  | ARS                      | peso
# Australia  | AUD                      | dollar
# Austria    | EUR                      | euro
# Azerbaijan | AZN                      | manat
# Belgium    | EUR                      | euro
# Bolivia    | BOB                      | boliviano
# Brazil     | BRL                      | real
# Bulgaria   | BGN                      | lev
# Canada     | CAD                      | dollar
# Chile      | CLP                      | peso
# ... (58 rows omitted)

# %%
currency_countries_set = set(final_currency_table.column("Country"))

missing_countries2 = egg_countries_set - currency_countries_set

print(f"Missing countries are: {missing_countries2}")
# Out:
# Missing countries are: {'Sri Lanka', 'Hong Kong', 'Vietnam', 'Ivory Coast', 'USA', 'South Africa', 'UA Emirates', 'Tanzania', 'Costa Rica', 'Bolivia', 'Russia', 'New Zealand', 'UK', 'South Korea', 'Saudi Arabia', 'Netherlands', 'Domin. Rep.', 'Puerto Rico', 'Philippines', 'Czechia'}

# %%
data = egg_price_table.with_columns("Sales Tax Rate (%)", final_tax_price_table.column("Sales Tax Rate (%)"))
data
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[122], line 1
# ----> 1 data = egg_price_table.with_columns("Sales Tax Rate (%)", final_tax_price_table.column("Sales Tax Rate (%)"))
#       2 data
#
# File c:\Users\Anees' Laptop\AppData\Local\Programs\Python\Python310\lib\site-packages\datascience\tables.py:2583, in Table.with_columns(self, *labels_and_values, **formatter)
#    2581 for i in range(0, len(labels_and_values), 2):
#    2582     label, values = labels_and_values[i], labels_and_values[i+1]
# -> 2583     self = self.with_column(label, values, formatter)
#    2584 return self
#
# File c:\Users\Anees' Laptop\AppData\Local\Programs\Python\Python310\lib\site-packages\datascience\tables.py:2500, in Table.with_column(self, label, values, formatter)
#    2498 elif isinstance(formatter, dict):
#    2499     formatter = formatter["formatter"]
# -> 2500 new_table.append_column(label, values, formatter)
#    2501 return new_table
#
# File c:\Users\Anees' Laptop\AppData\Local\Programs\Python\Python310\lib\site-packages\datascience\tables.py:991, in Table.append_column(self, label, values, formatter)
#     988         values = np.array(tuple(values))
#     990 if self.num_rows != 0 and len(values) != self.num_rows:
# --> 991     raise ValueError('Column length mismatch. New column does not have '
#     992                      'the same number of rows as table.')
#     993 else:
#     994     self._num_rows = len(values)
#
# ValueError: Column length mismatch. New column does not have the same number of rows as table.
